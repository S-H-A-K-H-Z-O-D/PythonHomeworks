# %%
import pandas as pd
import sqlite3

# %%
with sqlite3.connect('population.db') as con:
    df = pd.read_sql('select * from population', con=con)

df
# Out:
#           id first_name  last_name                             email  gender  \
# 0          1      Armin    Coltart              acoltart0@abc.net.au    Male
# 1          2        Mia  Tuddenham           mtuddenham1@addthis.com  Female
# 2          3   Kirsteni   Brafield            kbrafield2@arizona.edu  Female
# 3          4     Phylis    Furlong     pfurlong3@merriam-webster.com  Female
# 4          5     Wandis  Loveredge          wloveredge4@hatena.ne.jp  Female
# ...      ...        ...        ...                               ...     ...
# 11644  11645       Nell      Perez               nperezhy@flavors.me  Female
# 11645  11646        Ugo   Pethrick            upethrickhz@discuz.net    Male
# 11646  11647   Hartwell   Hadigate             hhadigatei0@cam.ac.uk    Male
# 11647  11648      Avrit     Bastin            abastini1@symantec.com  Female
# 11648  11649   Papageno   Buchanan  pbuchanani2@pagesperso-orange.fr    Male
#
#         salary                 state
# ...

# %%
df = df[(df['gender'] == 'Female') & (df['state'] == 'Florida') & (df['salary'] >= 1970000)]

# %%
df = df.drop(columns='id')

# %%
df
# Out:
#       first_name  last_name                             email  gender  \
# 0          Armin    Coltart              acoltart0@abc.net.au    Male
# 1            Mia  Tuddenham           mtuddenham1@addthis.com  Female
# 2       Kirsteni   Brafield            kbrafield2@arizona.edu  Female
# 3         Phylis    Furlong     pfurlong3@merriam-webster.com  Female
# 4         Wandis  Loveredge          wloveredge4@hatena.ne.jp  Female
# ...          ...        ...                               ...     ...
# 11644       Nell      Perez               nperezhy@flavors.me  Female
# 11645        Ugo   Pethrick            upethrickhz@discuz.net    Male
# 11646   Hartwell   Hadigate             hhadigatei0@cam.ac.uk    Male
# 11647      Avrit     Bastin            abastini1@symantec.com  Female
# 11648   Papageno   Buchanan  pbuchanani2@pagesperso-orange.fr    Male
#
#         salary                 state
# 0       368693  District of Columbia
# 1       154398               Florida
# ...

# %% [markdown]
# Task 1

# %%
df.columns = ['First Name', 'Last Name', 'Email', 'Gender', 'Salary', 'State']
df
# Out:
#       First Name  Last Name                             Email  Gender  \
# 0          Armin    Coltart              acoltart0@abc.net.au    Male
# 1            Mia  Tuddenham           mtuddenham1@addthis.com  Female
# 2       Kirsteni   Brafield            kbrafield2@arizona.edu  Female
# 3         Phylis    Furlong     pfurlong3@merriam-webster.com  Female
# 4         Wandis  Loveredge          wloveredge4@hatena.ne.jp  Female
# ...          ...        ...                               ...     ...
# 11644       Nell      Perez               nperezhy@flavors.me  Female
# 11645        Ugo   Pethrick            upethrickhz@discuz.net    Male
# 11646   Hartwell   Hadigate             hhadigatei0@cam.ac.uk    Male
# 11647      Avrit     Bastin            abastini1@symantec.com  Female
# 11648   Papageno   Buchanan  pbuchanani2@pagesperso-orange.fr    Male
#
#         Salary                 State
# 0       368693  District of Columbia
# 1       154398               Florida
# ...

# %% [markdown]
# Task 2

# %%
df2 = df[(df['Email'].str.endswith('@apache.org'))]
df2
# Out:
#       First Name    Last Name                      Email  Gender   Salary  \
# 15      Bearnard       Bazire        bbaziref@apache.org    Male   541515
# 667       Vachel  Fareweather  vfareweatherij@apache.org    Male  1829717
# 1994        Redd        Reeds        rreedsrm@apache.org    Male   761904
# 2141     Shaughn     Petrussi     spetrussi3x@apache.org    Male  1683091
# 2486     Norbert     Sharpley     nsharpleydi@apache.org    Male   293775
# 2707    Hugibert       Kilrow       hkilrowjn@apache.org    Male  1977836
# 3025      Winnie      Anersen       wanersenp@apache.org  Female  1607507
# 3894       Johny       Mushet       jmushetou@apache.org    Male   266039
# 3980    Thedrick     Clohisey     tclohiseyr8@apache.org    Male  1839591
# 4128    Mohandas       Heskey       mheskey3k@apache.org    Male  1721256
# 4312       Chere       Brixey       cbrixey8o@apache.org  Female  1333765
# 4400        Kerr       Bernth       kbernthb4@apache.org    Male  1521490
# ...

# %%
df2 = df2.groupby('Gender')['Email'].count()
df2
# Out:
# Gender
# Female     8
# Male      13
# Name: Email, dtype: int64

# %% [markdown]
# Task 3

# %%
df3 = df[(df['Gender'] == 'Male') & (df['Salary'] >= 1_000_000)]
len(df3)
# Out:
# 2848

# %% [markdown]
# Task 4

# %%
with sqlite3.connect('population.db') as con:
    df4 = pd.read_sql('select * from population', con=con)

df4 = df4.drop(columns='id')
df4.columns = ['First Name', 'Last Name', 'Email', 'Gender', 'Salary', 'State']

df4 = df4[
    (df4['Gender'] == 'Female') & 
    (df4['Salary'] <= 800_000) &
    (df4['State'] == "Alabama")
]
df4[['First Name', 'Last Name', 'Salary']]
# Out:
#        First Name    Last Name  Salary
# 11        Ronalda    Southcott  589810
# 172          Ilka       Stucke  336655
# 326         Monah       Cayton  376462
# 371         Helsa      Aartsen  794142
# 730        Dannie     Riccardo   78730
# 916         Lilia      Sappell   18515
# 947         Honey  Della Scala  743704
# 1033      Brianne  Rattenberie  438945
# 1177        Kasey        Biles  441852
# 1486         Erma  Matuszinski  416164
# 1633        Daryl       Assard  727663
# 1909        Randa    Husselbee  644219
# 2258      Lorilee         Wann  163832
# 2527     Maitilde        Jouen  105083
# 3127        Diana    Jovanovic  591147
# 3198         Liza      Frances  122187
# 3236       Yvette         Hoyt  166016
# 3247       Lucina       Clyant  529402
# 3676       Hattie      Bolding  151242
# 3776       Sherie     Tarquini  451697
# 4067         Lora       Lapere  434680
# 4243      Beitris        Viles  664515
# 4265        Karyn     Griffith  294921
# ...

# %% [markdown]
# Task 5

# %%
with sqlite3.connect('population.db') as con:
    df5 = pd.read_sql('select * from population', con=con)

df5 = df5.drop(columns='id')
df5.columns = ['First Name', 'Last Name', 'Email', 'Gender', 'Salary', 'State']

df5 = df5[
    (df5['State'] == 'Texas') &
    (df5['Email'].str.endswith('@patch.com'))
]

df5
# Out:
#      First Name Last Name                  Email  Gender   Salary  State
# 67     Lauretta   Creavin   lcreavin1v@patch.com  Female  1732422  Texas
# 2445    Ransell  Nornable  rnornablecd@patch.com    Male  1005095  Texas
# 4248       Poul    Revely    prevely6w@patch.com    Male   937957  Texas

# %% [markdown]
# Task 6

# %%
with sqlite3.connect('population.db') as con:
    df6 = pd.read_sql('select * from population', con=con)

df6 = df6.drop(columns='id')
df6.columns = ['First Name', 'Last Name', 'Email', 'Gender', 'Salary', 'State']

df6 = df6[
    (df6['Gender'] == 'Male') &
    (df6['State'] == 'California') &
    (df6['Salary'] >= 400_000) &
    (df6['Salary'] < 800_000)
]

df6
# Out:
#       First Name  Last Name                           Email Gender  Salary  \
# 49        August  D'Ambrosi         adambrosi1d@jiathis.com   Male  741351
# 157    Francklyn       Eake               feake4d@imgur.com   Male  699509
# 206        Cesar      Agott   cagott5q@networksolutions.com   Male  676165
# 592         Meir    Ughelli         mughelligg@yolasite.com   Male  691914
# 675         Darb    Galland  dgallandir@businessinsider.com   Male  500834
# ...          ...        ...                             ...    ...     ...
# 11034       Will    Cuseick      wcuseick10@liveinternet.ru   Male  712473
# 11044    Barnaby     Yexley             byexley1a@google.es   Male  444002
# 11211     Peyter   Sedgwick             psedgwick5x@npr.org   Male  501478
# 11412   Anatollo     Fearon             afearonbi@fotki.com   Male  674162
# 11627    Gerrard     Bridge   gbridgehh@creativecommons.org   Male  756029
#
#             State
# 49     California
# 157    California
# ...

# %% [markdown]
# Task 7

# %%
with sqlite3.connect('population.db') as con:
    df7 = pd.read_sql('select * from population', con=con)

df7 = df7.drop(columns='id')
df7.columns = ['First Name', 'Last Name', 'Email', 'Gender', 'Salary', 'State']

df7 = df7[
    (df7['Gender'] == 'Female') &
    (df7['Salary'] >= 500_000)
]

df7
# Out:
#       First Name   Last Name                           Email  Gender   Salary  \
# 2       Kirsteni    Brafield          kbrafield2@arizona.edu  Female  1230304
# 3         Phylis     Furlong   pfurlong3@merriam-webster.com  Female  1567795
# 4         Wandis   Loveredge        wloveredge4@hatena.ne.jp  Female  1136950
# 9          Devan     Tunmore          dtunmore9@symantec.com  Female  1092918
# 10          Addi   Rucklesse           arucklessea@upenn.edu  Female  1811361
# ...          ...         ...                             ...     ...      ...
# 11628      Rhody  MacCulloch  rmaccullochhi@chronoengine.com  Female   625167
# 11630        Ana       Roony           aroonyhk@redcross.org  Female  1692096
# 11638       Ania     Scotson            ascotsonhs@wiley.com  Female   728155
# 11644       Nell       Perez             nperezhy@flavors.me  Female  1909496
# 11647      Avrit      Bastin          abastini1@symantec.com  Female  1869988
#
#               State
# ...

# %% [markdown]
# Task 8

# %%
with sqlite3.connect('population.db') as con:
    df8 = pd.read_sql('select * from population', con=con)

df8 = df8.drop(columns='id')
df8.columns = ['First Name', 'Last Name', 'Email', 'Gender', 'Salary', 'State']

df8 = df8[df8['State'] == 'Georgia'].sort_values('Salary', ascending=False)
df8.head(10)
# Out:
#      First Name Last Name                        Email  Gender   Salary  \
# 7635    Susette    Emeney           semeneyhn@bing.com  Female  1999095
# 2330    Emeline     Bebis        ebebis96@stanford.edu  Female  1997605
# 4951       Evyn   Watkins   ewatkinsqf@hugedomains.com    Male  1994162
# 6008    Hillyer    Praton             hpraton8@hhs.gov    Male  1993907
# 658    Robinett     Mucci        rmucciia@netvibes.com  Female  1989791
# 46       Verile   Binding      vbinding1a@vkontakte.ru  Female  1985757
# 9490  Harriette   Bonwick       hbonwickdn@foxnews.com  Female  1970839
# 739       Anita    Vowles  avowleskj@printfriendly.com  Female  1965112
# 4081      Tiffi  Lansdown    tlansdown29@shinystat.com  Female  1962952
# 3262    Haslett     Nevin          hnevin7a@rediff.com    Male  1960207
#
#         State
# 7635  Georgia
# 2330  Georgia
# 4951  Georgia
# 6008  Georgia
# 658   Georgia
# 46    Georgia
# 9490  Georgia
# 739   Georgia
# 4081  Georgia
# 3262  Georgia

# %% [markdown]
# Task 9

# %%
with sqlite3.connect('population.db') as con:
    df9 = pd.read_sql('select * from population', con=con)

df9 = df9.drop(columns='id')
df9.columns = ['First Name', 'Last Name', 'Email', 'Gender', 'Salary', 'State']

df9 = df9[
    (df9['Last Name'].str[0] == 'S') &
    (df9['Salary'] >= 300_000)
]

len(df9)
# Out:
# 951

# %% [markdown]
# Task 10

# %%
with sqlite3.connect('population.db') as con:
    df10 = pd.read_sql('select * from population', con=con)

df10 = df10.drop(columns='id')
df10.columns = ['First Name', 'Last Name', 'Email', 'Gender', 'Salary', 'State']

df10 = df10[
    (df10['Gender'] == 'Female') &
    (df10['State'] == 'Oklahoma')
]

avgSal = df10['Salary'].mean()

print(avgSal)
# Out:
# 1020987.7195121951

# %% [markdown]
# Task 11

# %%
with sqlite3.connect('population.db') as con:
    df11 = pd.read_sql('select * from population', con=con)

df11 = df11.drop(columns='id')
df11.columns = ['First Name', 'Last Name', 'Email', 'Gender', 'Salary', 'State']

df11 = df11[
    (df11['State'] == 'Florida') &
    (df11['Email'].str.endswith('.net'))
]

df11
# Out:
#          First Name    Last Name                         Email  Gender  \
# 327            Coop     Chaimson   cchaimson93@themeforest.net    Male
# 818            Jobi      Cutmere         jcutmeremq@cpanel.net  Female
# 924           Chris     Garfirth       cgarfirthpo@behance.net  Female
# 1101          Waite    Rudderham       wrudderham2t@seesaa.net    Male
# 1242             Em      Graffin      egraffin6q@clickbank.net  Female
# 1357      Patrizius   Matskevich     pmatskevich9x@comcast.net    Male
# 1718        Malanie      Harkins         mharkinsjy@seesaa.net  Female
# 1767          Abbie       Isenor             aisenorlb@php.net    Male
# 1996        Eugenio      Halhead         ehalheadro@discuz.net    Male
# 2515          Hobey      Licence            hlicenceeb@ovh.net    Male
# 3622         Fallon        Bothe               fbotheha@a8.net  Female
# 3842           Geri         Tink           gtinkne@comcast.net    Male
# ...

# %% [markdown]
# Task 12

# %%
with sqlite3.connect('population.db') as con:
    df12 = pd.read_sql('select * from population', con=con)

df12 = df12.drop(columns='id')
df12.columns = ['First Name', 'Last Name', 'Email', 'Gender', 'Salary', 'State']

df12 = df12[
    (df12['First Name'].str[0] == 'K') &
    (df12['Salary'] >= 1_000_000)
]

print(len(df12))
# Out:
# 243

# %% [markdown]
# Task 13

# %%
with sqlite3.connect('population.db') as con:
    df13 = pd.read_sql('select * from population', con=con)

df13 = df13.drop(columns='id')
df13.columns = ['First Name', 'Last Name', 'Email', 'Gender', 'Salary', 'State']

df13 = df13[
    (df13['Email'].str.endswith('addthis.com')) &
    (df13['Salary'] <= 200_000)
]

df13
# Out:
#      First Name  Last Name                    Email  Gender  Salary  \
# 1           Mia  Tuddenham  mtuddenham1@addthis.com  Female  154398
# 3815     Bordie     Newick    bnewickmn@addthis.com    Male  175611
#
#            State
# 1        Florida
# 3815  California

# %% [markdown]
# Task 14

# %%
with sqlite3.connect('population.db') as con:
    df14 = pd.read_sql('select * from population', con=con)

df14 = df14.drop(columns='id')
df14.columns = ['First Name', 'Last Name', 'Email', 'Gender', 'Salary', 'State']

df14 = df14[(df14['Gender'] == 'Male')].sort_values('Salary')

df14.head(1)
# Out:
#      First Name Last Name            Email Gender  Salary  State
# 3570     Milton    Nairns  mnairnsfu@51.la   Male     241  Texas

# %% [markdown]
# Task 15

# %%
with sqlite3.connect('population.db') as con:
    df15 = pd.read_sql('select * from population', con=con)

df15 = df15.drop(columns='id')
df15.columns = ['First Name', 'Last Name', 'Email', 'Gender', 'Salary', 'State']

df15 = df15[
    (df15['State'] == 'California') &
    (df15['Salary'] >= 800_000) &
    (df15['Gender'] == 'Female')
]

print(len(df15))
# Out:
# 400

# %% [markdown]
# Task 16

# %%
with sqlite3.connect('population.db') as con:
    df16 = pd.read_sql('select * from population', con=con)

df16 = df16.drop(columns='id')
df16.columns = ['First Name', 'Last Name', 'Email', 'Gender', 'Salary', 'State']

df16 = df16[
    (df16['Gender'] == 'Male') &
    (df16['Salary'] >= 1_000_000)
]

df16[['First Name', 'Salary']]
# Out:
#       First Name   Salary
# 13     Sebastien  1133137
# 19           Pat  1424714
# 22       Gilburt  1034660
# 24          Omar  1727275
# 26       Raymund  1096837
# ...          ...      ...
# 11634        Ruy  1212833
# 11635       Tome  1159395
# 11636      Kirby  1911043
# 11642     Briant  1607225
# 11648   Papageno  1271538
#
# [2848 rows x 2 columns]

# %% [markdown]
# Task 17

# %%
with sqlite3.connect('population.db') as con:
    df17 = pd.read_sql('select * from population', con=con)

df17 = df17.drop(columns='id')
df17.columns = ['First Name', 'Last Name', 'Email', 'Gender', 'Salary', 'State']

df17 = df17[
    (df17['Email'].str.contains('edu')) &
    (df17['Salary'] >= 1_500_000)
]

df17
# Out:
#       First Name   Last Name                      Email  Gender   Salary  \
# 10          Addi   Rucklesse      arucklessea@upenn.edu  Female  1811361
# 72      Granthem   Essberger  gessberger20@illinois.edu    Male  1587610
# 100          Gun      Cutler     gcutler2s@virginia.edu    Male  1673082
# 150       Caresa       Takis      ctakis46@illinois.edu  Female  1605712
# 235    Gaultiero      Duddle       gduddle6j@utexas.edu    Male  1989965
# ...          ...         ...                        ...     ...      ...
# 11383        Nye      Cloutt          nclouttap@mit.edu    Male  1567717
# 11402     Sylvia     Millins         smillinsb8@umn.edu  Female  1605004
# 11554        Von    McKinnon         vmckinnonfg@si.edu    Male  1518998
# 11602     Krissy    Goosnell      kgoosnellgs@upenn.edu  Female  1549112
# 11636      Kirby  Sitlington    ksitlingtonhq@umich.edu    Male  1911043
#
#                       State
# 10                 New York
# 72               New Jersey
# ...

# %% [markdown]
# Task 18

# %%
with sqlite3.connect('population.db') as con:
    df18 = pd.read_sql('select * from population', con=con)

df18 = df18.drop(columns='id')
df18.columns = ['First Name', 'Last Name', 'Email', 'Gender', 'Salary', 'State']

df18 = df18[
    (df18['State'] == 'Alabama') &
    (df18['Salary'] <= 100_000)
]

print(len(df18))
# Out:
# 5

# %% [markdown]
# Task 19

# %%
with sqlite3.connect('population.db') as con:
    df19 = pd.read_sql('select * from population', con=con)

df19 = df19.drop(columns='id')
df19.columns = ['First Name', 'Last Name', 'Email', 'Gender', 'Salary', 'State']

df19 = df19[
    (df19['Last Name'].str.endswith('n')) &
    (df19['Salary'] <= 600_000)
]

df19
# Out:
#       First Name  Last Name                        Email  Gender  Salary  \
# 5          Denis     Martyn             dmartyn5@unc.edu    Male  547205
# 7           Jone     Pegden      jpegden7@washington.edu    Male  327962
# 50         Tucky     Durgan     tdurgan1e@opensource.org    Male  479416
# 52          Devy  Ronaldson   dronaldson1g@biglobe.ne.jp    Male  508791
# 64      Nikolaus      Zoren       nzoren1s@tuttocitta.it    Male  427155
# ...          ...        ...                          ...     ...     ...
# 11484     Florri      Posen         fposendi@cbsnews.com  Female  536220
# 11527        Red    Goddman      rgoddmanep@gravatar.com    Male  545977
# 11549     Dollie  Nicholson    dnicholsonfb@slashdot.org  Female  476674
# 11551        Hal     Pashan            hpashanfd@psu.edu    Male  528449
# 11580      Cyndi    Starten  cstarteng6@reverbnation.com  Female  411907
#
#                State
# 5        Connecticut
# 7         California
# 50      South Dakota
# ...

# %% [markdown]
# Task 20

# %%
with sqlite3.connect('population.db') as con:
    df20 = pd.read_sql('select * from population', con=con)

df20 = df20.drop(columns='id')
df20.columns = ['First Name', 'Last Name', 'Email', 'Gender', 'Salary', 'State']

df20 = df20[df20['State'] == 'District of Columbia'].sort_values('Salary', ascending=False)

df20.head(1)
# Out:
#      First Name Last Name                       Email Gender   Salary  \
# 9386      Bryan     Boddy  bboddyar@timesonline.co.uk   Male  1997136
#
#                      State
# 9386  District of Columbia

# %% [markdown]
# Task 21

# %%
with sqlite3.connect('population.db') as con:
    df21 = pd.read_sql('select * from population', con=con)

df21 = df21.drop(columns='id')
df21.columns = ['First Name', 'Last Name', 'Email', 'Gender', 'Salary', 'State']

df21 = df21[
    (df21['Gender'] == 'Female') &
    (df21['State'] == 'New York') &
    (df21['Salary'] >= 500_000) &
    (df21['Salary'] < 1_000_000)
]

df21
# Out:
#        First Name      Last Name                             Email  Gender  \
# 42        Auroora        Startin               astartin16@webs.com  Female
# 81     Anna-diana           Lean                alean29@oracle.com  Female
# 173          Erma         Grimes              egrimes4t@senate.gov  Female
# 174       Allissa         Degoey                adegoey4u@1688.com  Female
# 193        Imogen  De la Yglesia       idelayglesia5d@slashdot.org  Female
# ...           ...            ...                               ...     ...
# 10980    Lizabeth      Corneille  lcorneillera@cargocollective.com  Female
# 11069       Bride        Tennock              btennock1z@skype.com  Female
# 11115    Rosmunda        Rolston            rrolston39@yahoo.co.jp  Female
# 11473     Teriann         Gawler         tgawlerd7@telegraph.co.uk  Female
# 11622    Margaret        Sleicht             msleichthc@forbes.com  Female
#
#        Salary     State
# 42     612491  New York
# ...

# %% [markdown]
# Task 22

# %%
with sqlite3.connect('population.db') as con:
    df22 = pd.read_sql('select * from population', con=con)

df22 = df22.drop(columns='id')
df22.columns = ['First Name', 'Last Name', 'Email', 'Gender', 'Salary', 'State']

df22 = df22[
    (df22['Email'].str.contains('yahoo.com')) &
    (df22['State'] == 'Texas')
]

df22
# Out:
#      First Name Last Name                  Email  Gender   Salary  State
# 6485   Johnette  Goldsack  jgoldsackdh@yahoo.com  Female  1430229  Texas

# %% [markdown]
# Task 23

# %%
with sqlite3.connect('population.db') as con:
    df23 = pd.read_sql('select * from population', con=con)

df23 = df23.drop(columns='id')
df23.columns = ['First Name', 'Last Name', 'Email', 'Gender', 'Salary', 'State']

df23 = df23[
    (df23['State'] == 'California') &
    (df23['Gender'] == 'Male')
]

avgSal = df23['Salary'].mean()
avgSal

res = df23[df23['Salary'] <= avgSal]
res
# Out:
#       First Name  Last Name                          Email Gender  Salary  \
# 7           Jone     Pegden        jpegden7@washington.edu   Male  327962
# 49        August  D'Ambrosi        adambrosi1d@jiathis.com   Male  741351
# 86        Emmott    Smeeton      esmeeton2e@guardian.co.uk   Male  390998
# 157    Francklyn       Eake              feake4d@imgur.com   Male  699509
# 204        Ferdy   Dumbrall           fdumbrall5o@tamu.edu   Male  865124
# ...          ...        ...                            ...    ...     ...
# 11412   Anatollo     Fearon            afearonbi@fotki.com   Male  674162
# 11427     Pepito      Asaaf            pasaafbx@seesaa.net   Male  943060
# 11453     Tammie    Whybray              twhybraycn@un.org   Male    3888
# 11504     Morten    Biddiss               mbiddisse2@ow.ly   Male  304470
# 11627    Gerrard     Bridge  gbridgehh@creativecommons.org   Male  756029
#
#             State
# 7      California
# 49     California
# 86     California
# ...
